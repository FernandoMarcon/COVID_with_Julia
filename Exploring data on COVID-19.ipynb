# %% [markdown]
# # Exploring data on COVID-19

# %% [markdown]
# $y = x^2$

# %%
url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
# Out:
# "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"

# %%
url
# Out:
# "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"

# %% [markdown]
#   $y = x²$

# %%
typeof(url)
# Out:
# String

# %%
*
# Out:
# * (generic function with 328 methods)

# %%
methods(*)
# Out:
# # 328 methods for generic function "*":
# [1] *(x::T, y::T) where T<:Union{Int128, UInt128} in Base at int.jl:908
# [2] *(x::T, y::T) where T<:Union{Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8} in Base at int.jl:88
# [3] *(s1::Union{AbstractChar, AbstractString}, ss::Union{AbstractChar, AbstractString}...) in Base at strings/basic.jl:260
# [4] *(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigInt) in Base.GMP at gmp.jl:539
# [5] *(c::Union{Int16, Int32, Int64, Int8}, x::BigInt) in Base.GMP at gmp.jl:541
# [6] *(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigFloat) in Base.MPFR at mpfr.jl:376
# [7] *(c::Union{Int16, Int32, Int64, Int8}, x::BigFloat) in Base.MPFR at mpfr.jl:384
# [8] *(c::Union{Float16, Float32, Float64}, x::BigFloat) in Base.MPFR at mpfr.jl:392
# [9] *(A::StridedMatrix{T}, x::StridedVector{S}) where {T<:Union{Float32, Float64, ComplexF32, ComplexF64}, S<:Real} in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:44
# [10] *(A::StridedMatrix{var"#s832"} where var"#s832"<:Union{Float32, Float64}, B::StridedMatrix{var"#s831"} where var"#s831"<:Union{Float32, Float64, ComplexF32, ComplexF64}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:158
# [11] *(A::StridedMatrix{var"#s832"} where var"#s832"<:Union{ComplexF32, ComplexF64}, B::StridedMatrix{var"#s831"} where var"#s831"<:Union{ComplexF32, ComplexF64}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:162
# [12] *(A::StridedMatrix{T} where T, Q::LinearAlgebra.AbstractQ) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/qr.jl:680
# [13] *(A::StridedMatrix{T} where T, adjB::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractQ}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/qr.jl:720
# [14] *(A::StridedVecOrMat{T} where T, adjQ::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.LQPackedQ}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/lq.jl:254
# [15] *(A::StridedVecOrMat{T} where T, Q::LinearAlgebra.LQPackedQ) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/lq.jl:278
# [16] *(A::Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}} where {T, S}, B::Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}} where {T, S}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:572
# [17] *(A::Union{LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular}, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/bidiag.jl:640
# [18] *(A::Union{LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:Union{LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular}}, LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:Union{LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular}}}, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/bidiag.jl:649
# [19] *(A::Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular}, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/bidiag.jl:658
# [20] *(A::Union{LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular}}, LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular}}}, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/bidiag.jl:667
# [21] *(A::Union{LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal}, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/bidiag.jl:676
# [22] *(A::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.Tridiagonal}, B::LinearAlgebra.Diagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/bidiag.jl:717
# [23] *(X::StridedArray{P, N} where N, y::Real) where P<:Dates.Period in Dates at /opt/julia-1.6.0/share/julia/stdlib/v1.6/Dates/src/deprecated.jl:44
# [24] *(x::Union{SparseArrays.SparseVector{Tv, Ti}, SubArray{Tv, 1, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, false} where var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 1, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}}, false} where var"#s832"<:SparseArrays.AbstractSparseVector{Tv, Ti}} where {Tv, Ti}, a::Number) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/sparsevector.jl:1448
# [25] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{TA, Ti}, SubArray{TA, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{TA, Ti}, L}} where Ti, x::Union{StridedVector{T} where T, BitVector}) where TA in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:50
# [26] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}, LinearAlgebra.LowerTriangular{Tv, var"#s831"} where var"#s831"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}, LinearAlgebra.UpperTriangular{Tv, var"#s832"} where var"#s832"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}} where {Tv, Ti}, B::SubArray{Tv, 1, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, false} where {Tv, Ti, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:164
# [27] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}, LinearAlgebra.LowerTriangular{Tv, var"#s831"} where var"#s831"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}, LinearAlgebra.UpperTriangular{Tv, var"#s832"} where var"#s832"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}} where {Tv, Ti}, B::SubArray{Tv, 1, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}}, false} where {Tv, Ti, var"#s832"<:SparseArrays.AbstractSparseVector{Tv, Ti}}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:165
# [28] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}} where {Tv, Ti}, B::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}} where {Tv, Ti}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:166
# [29] *(A::Union{LinearAlgebra.LowerTriangular{Tv, var"#s831"} where var"#s831"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}, LinearAlgebra.UpperTriangular{Tv, var"#s832"} where var"#s832"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}} where {Tv, Ti}, B::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}} where {Tv, Ti}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:167
# [30] *(X::Union{LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}, A::Union{SparseArrays.AbstractSparseMatrixCSC{TvA, Ti}, SubArray{TvA, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{TvA, Ti}, L}} where Ti) where TvA in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:114
# [31] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}} where {Tv, Ti}, B::Union{LinearAlgebra.LowerTriangular{Tv, var"#s831"} where var"#s831"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}, LinearAlgebra.UpperTriangular{Tv, var"#s832"} where var"#s832"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}} where {Tv, Ti}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:168
# [32] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{TA, Ti}, SubArray{TA, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{TA, Ti}, L}} where Ti, B::Union{LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}) where TA in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:52
# [33] *(A::Union{LinearAlgebra.LowerTriangular{Tv, var"#s831"} where var"#s831"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}, LinearAlgebra.UpperTriangular{Tv, var"#s832"} where var"#s832"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}} where {Tv, Ti}, B::Union{LinearAlgebra.LowerTriangular{Tv, var"#s831"} where var"#s831"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}, LinearAlgebra.UpperTriangular{Tv, var"#s832"} where var"#s832"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}} where {Tv, Ti}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:169
# [34] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}, LinearAlgebra.LowerTriangular{Tv, var"#s831"} where var"#s831"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}, LinearAlgebra.UpperTriangular{Tv, var"#s832"} where var"#s832"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}} where {Tv, Ti}, B::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SparseArrays.AbstractSparseMatrixCSC}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:170
# [35] *(X::Union{LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}, adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SparseArrays.AbstractSparseMatrixCSC}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:139
# [36] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}, LinearAlgebra.LowerTriangular{Tv, var"#s831"} where var"#s831"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}, LinearAlgebra.UpperTriangular{Tv, var"#s832"} where var"#s832"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}} where {Tv, Ti}, B::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SparseArrays.AbstractSparseMatrixCSC}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:171
# [37] *(X::Union{LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}, transA::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SparseArrays.AbstractSparseMatrixCSC}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:141
# [38] *(A::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal}, B::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/SparseArrays.jl:58
# [39] *(A::Union{SparseArrays.SparseMatrixCSC{Float64, Ti}, SparseArrays.SparseVector{Float64, Ti}}, B::LinearAlgebra.Symmetric{Float64, SparseArrays.SparseMatrixCSC{Float64, Ti}}) where Ti in SuiteSparse.CHOLMOD at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SuiteSparse/src/cholmod.jl:1869
# [40] *(A::Union{SparseArrays.SparseMatrixCSC{ComplexF64, Ti}, SparseArrays.SparseVector{ComplexF64, Ti}}, B::LinearAlgebra.Hermitian{ComplexF64, SparseArrays.SparseMatrixCSC{ComplexF64, Ti}}) where Ti in SuiteSparse.CHOLMOD at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SuiteSparse/src/cholmod.jl:1871
# [41] *(A::Union{SparseArrays.SparseMatrixCSC{Float64, Ti}, SparseArrays.SparseVector{Float64, Ti}}, B::LinearAlgebra.Hermitian{Float64, SparseArrays.SparseMatrixCSC{Float64, Ti}}) where Ti in SuiteSparse.CHOLMOD at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SuiteSparse/src/cholmod.jl:1873
# [42] *(index::CartesianIndex, a::Integer) in Base.IteratorsMD at multidimensional.jl:124
# [43] *(adjQ::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractQ}, B::StridedVecOrMat{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/qr.jl:628
# [44] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:StridedMatrix{T}}, x::StridedVector{S}) where {T<:Union{Float32, Float64, ComplexF32, ComplexF64}, S} in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:105
# [45] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.LQPackedQ}, B::StridedVecOrMat{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/lq.jl:202
# [46] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SparseArrays.AbstractSparseMatrixCSC}, x::Union{StridedVector{T} where T, BitVector}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:78
# [47] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SparseArrays.AbstractSparseMatrixCSC}, B::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}, LinearAlgebra.LowerTriangular{Tv, var"#s831"} where var"#s831"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}, LinearAlgebra.UpperTriangular{Tv, var"#s832"} where var"#s832"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}} where {Tv, Ti}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:173
# [48] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SparseArrays.AbstractSparseMatrixCSC}, B::Union{LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix{T} where T, BitMatrix}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:80
# [49] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(StridedVecOrMat{T} where T)}, Q::LinearAlgebra.AbstractQ) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/qr.jl:738
# [50] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SuiteSparse.CHOLMOD.Sparse}, B::SuiteSparse.CHOLMOD.Dense) in SuiteSparse.CHOLMOD at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SuiteSparse/src/cholmod.jl:1268
# [51] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, adjB::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:616
# [52] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, adjB::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:620
# [53] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, adjB::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}, LinearAlgebra.Symmetric{Complex{T}, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:621
# [54] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, adjB::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:618
# [55] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}, LinearAlgebra.Symmetric{Complex{T}, S}} where {T<:Real, S})}, adjB::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:619
# [56] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, adjB::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:617
# [57] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(StridedMatrix{T} where T)}, adjQ::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:LinearAlgebra.LQPackedQ}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/lq.jl:259
# [58] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.LQPackedQ}, adjB::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(StridedVecOrMat{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/lq.jl:222
# [59] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(StridedVecOrMat{T} where T)}, adjQ::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:LinearAlgebra.AbstractQ}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/qr.jl:745
# [60] *(u::LinearAlgebra.Adjoint{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)}, v::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(LinearAlgebra.Transpose{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/adjtrans.jl:311
# [61] *(adjQ::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractQ}, adjB::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(StridedVecOrMat{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/qr.jl:642
# [62] *(u::LinearAlgebra.Adjoint{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)}, A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractQ}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/qr.jl:734
# [63] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractTriangular}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1069
# [64] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:LinearAlgebra.AbstractTriangular}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1073
# [65] *(D::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.Diagonal}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:LinearAlgebra.Diagonal}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:288
# [66] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, adjD::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:LinearAlgebra.Diagonal}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:393
# [67] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(AbstractVector{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1059
# [68] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(AbstractMatrix{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1060
# [69] *(adjD::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.Diagonal}, adjA::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:394
# [70] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractVector{T} where T)}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1050
# [71] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1051
# [72] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractTriangular}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:LinearAlgebra.AbstractRotation}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/givens.jl:407
# [73] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:LinearAlgebra.AbstractRotation}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/givens.jl:409
# [74] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractVector{T} where T)}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:LinearAlgebra.AbstractRotation}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/givens.jl:402
# [75] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:LinearAlgebra.AbstractRotation}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/givens.jl:403
# [76] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SparseArrays.AbstractSparseMatrixCSC}, B::LinearAlgebra.Adjoint{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:SparseArrays.AbstractSparseMatrixCSC}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:174
# [77] *(u::LinearAlgebra.Adjoint{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)}, v::LinearAlgebra.Adjoint{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/adjtrans.jl:305
# [78] *(u::LinearAlgebra.Adjoint{var"#s832", var"#s8321"} where {var"#s832"<:Number, var"#s8321"<:(AbstractVector{T} where T)}, v::AbstractVector{var"#s831"} where var"#s831"<:Number) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/adjtrans.jl:296
# [79] *(D::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.Diagonal}, B::LinearAlgebra.Diagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:247
# [80] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractTriangular}, D::LinearAlgebra.Diagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:248
# [81] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::LinearAlgebra.Diagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:390
# [82] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}, D::LinearAlgebra.Diagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:250
# [83] *(x::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractVector{T} where T)}, D::LinearAlgebra.Diagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:694
# [84] *(x::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractVector{T} where T)}, D::LinearAlgebra.Diagonal, y::AbstractVector{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:696
# [85] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:Union{DenseMatrix{Ta}, Base.ReinterpretArray{Ta, 2, S, A, IsReshaped} where {A<:Union{SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, IsReshaped, S}, Base.ReshapedArray{Ta, 2, A, MI} where {A<:Union{Base.ReinterpretArray{T, N, S, A, IsReshaped} where {T, N, A<:Union{SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, IsReshaped, S}, SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, N} where N}}, SubArray{Ta, 2, A, I, L} where {A<:Union{Base.ReinterpretArray{T, N, S, A, IsReshaped} where {T, N, A<:Union{SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, IsReshaped, S}, Base.ReshapedArray{T, N, A, MI} where {T, N, A<:Union{Base.ReinterpretArray{T, N, S, A, IsReshaped} where {T, N, A<:Union{SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, IsReshaped, S}, SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, N} where N}}, DenseArray}, I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex, Base.ReshapedArray{T, N, A, Tuple{}} where {T, N, A<:AbstractUnitRange}}, N} where N}, L}, LinearAlgebra.LowerTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UnitLowerTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UnitUpperTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UpperTriangular{Ta, S} where S<:AbstractMatrix{Ta}}}, x::SparseArrays.AbstractSparseVector{Tx, Ti} where Ti) where {Ta, Tx} in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/sparsevector.jl:1616
# [86] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SparseArrays.AbstractSparseMatrixCSC}, x::SparseArrays.AbstractSparseVector{Tv, Ti} where {Tv, Ti}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/sparsevector.jl:1771
# [87] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SuiteSparse.CHOLMOD.Sparse}, B::SuiteSparse.CHOLMOD.Sparse) in SuiteSparse.CHOLMOD at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SuiteSparse/src/cholmod.jl:1258
# [88] *(u::LinearAlgebra.Adjoint{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)}, v::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(LinearAlgebra.Adjoint{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/adjtrans.jl:313
# [89] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}, LinearAlgebra.Symmetric{Complex{T}, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1047
# [90] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractTriangular}, B::LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}, LinearAlgebra.Symmetric{Complex{T}, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1070
# [91] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractVector{T} where T)}, B::LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}, LinearAlgebra.Symmetric{Complex{T}, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1052
# [92] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}, B::LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}, LinearAlgebra.Symmetric{Complex{T}, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1053
# [93] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:LinearAlgebra.AbstractTriangular}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1074
# [94] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(AbstractVector{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1061
# [95] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::LinearAlgebra.Transpose{var"#s830", var"#s829"} where {var"#s830", var"#s829"<:(AbstractMatrix{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:1062
# [96] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:SuiteSparse.CHOLMOD.Sparse}, B::VecOrMat{T} where T) in SuiteSparse.CHOLMOD at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SuiteSparse/src/cholmod.jl:1270
# [97] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(StridedMatrix{T} where T)}, Q::LinearAlgebra.LQPackedQ) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/lq.jl:290
# [98] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:626
# [99] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::AbstractVector{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:605
# [100] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:AbstractMatrix{T}}, x::AbstractVector{S}) where {T, S} in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:110
# [101] *(adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}, B::AbstractMatrix{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:606
# [102] *(A::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:1710
# [103] *(v::LinearAlgebra.Adjoint{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)}, A::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:1702
# [104] *(x::LinearAlgebra.Adjoint{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)}, A::AbstractMatrix{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:133
# [105] *(y::Integer, x::Rational) in Base at rational.jl:317
# [106] *(a::Integer, index::CartesianIndex{N}) where N in Base.IteratorsMD at multidimensional.jl:123
# [107] *(A::LinearAlgebra.Diagonal, B::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.Tridiagonal}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/bidiag.jl:722
# [108] *(Da::LinearAlgebra.Diagonal, Db::LinearAlgebra.Diagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:178
# [109] *(D::LinearAlgebra.Diagonal, A::SparseArrays.AbstractSparseMatrixCSC) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:144
# [110] *(A::LinearAlgebra.Diagonal, transB::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}, LinearAlgebra.Symmetric{Complex{T}, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:387
# [111] *(D::LinearAlgebra.Diagonal, B::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractTriangular}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:279
# [112] *(D::LinearAlgebra.Diagonal, B::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.Diagonal}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:278
# [113] *(D::LinearAlgebra.Diagonal, transA::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:281
# [114] *(A::LinearAlgebra.Diagonal, B::LinearAlgebra.SymTridiagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/bidiag.jl:727
# [115] *(D::LinearAlgebra.Diagonal, x::Number) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:175
# [116] *(D::LinearAlgebra.Diagonal, adjQ::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:Union{LinearAlgebra.QRCompactWYQ, LinearAlgebra.QRPackedQ}}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:270
# [117] *(D::LinearAlgebra.Diagonal, B::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractTriangular}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:268
# [118] *(D::LinearAlgebra.Diagonal, B::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.Diagonal}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:267
# [119] *(A::LinearAlgebra.Diagonal, adjB::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:389
# [120] *(D::LinearAlgebra.Diagonal, adjA::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:271
# [121] *(A::LinearAlgebra.Diagonal, B::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractRotation}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/givens.jl:412
# [122] *(D::LinearAlgebra.Diagonal, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:196
# [123] *(D::LinearAlgebra.Diagonal, A::AbstractMatrix{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:201
# [124] *(D::LinearAlgebra.Diagonal, V::AbstractVector{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:186
# [125] *(x::Base.TwicePrecision{var"#s79"} where var"#s79"<:Union{Float16, Float32, Float64}, v::Integer) in Base at twiceprecision.jl:288
# [126] *(x::Base.TwicePrecision, v::Number) in Base at twiceprecision.jl:284
# [127] *(x::Base.TwicePrecision{T}, y::Base.TwicePrecision{T}) where T in Base at twiceprecision.jl:296
# [128] *(x::Base.TwicePrecision, y::Base.TwicePrecision) in Base at twiceprecision.jl:301
# [129] *(transA::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:StridedMatrix{T}}, x::StridedVector{S}) where {T<:Union{Float32, Float64, ComplexF32, ComplexF64}, S} in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:84
# ...
# [237] *(A::LinearAlgebra.Hermitian, x::Real) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:632
# [238] *(A::LinearAlgebra.Hermitian{ComplexF64, SparseArrays.SparseMatrixCSC{ComplexF64, Ti}}, B::Union{SparseArrays.SparseMatrixCSC{ComplexF64, Ti}, SparseArrays.SparseVector{ComplexF64, Ti}}) where Ti in SuiteSparse.CHOLMOD at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SuiteSparse/src/cholmod.jl:1864
# [239] *(A::LinearAlgebra.Hermitian{Float64, SparseArrays.SparseMatrixCSC{Float64, Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Float64, Ti}, SparseArrays.SparseVector{Float64, Ti}}) where Ti in SuiteSparse.CHOLMOD at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SuiteSparse/src/cholmod.jl:1866
# [240] *(x::Rational, y::Integer) in Base at rational.jl:313
# [241] *(A::LinearAlgebra.AbstractTriangular, transB::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}, LinearAlgebra.Symmetric{Complex{T}, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:625
# [242] *(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:1713
# [243] *(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.Transpose{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:2220
# [244] *(A::LinearAlgebra.AbstractTriangular, adjB::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:627
# [245] *(A::LinearAlgebra.AbstractTriangular, D::LinearAlgebra.Diagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:194
# [246] *(A::LinearAlgebra.AbstractTriangular, B::Union{LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/bidiag.jl:630
# [247] *(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractRotation}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/givens.jl:413
# [248] *(A::LinearAlgebra.AbstractTriangular, adjB::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:Union{LinearAlgebra.QRCompactWYQ, LinearAlgebra.QRPackedQ}}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/special.jl:285
# [249] *(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:1712
# [250] *(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.Adjoint{T, var"#s832"} where {T, var"#s832"<:(AbstractVector{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:2219
# [251] *(A::LinearAlgebra.UpperTriangular, x::Number) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:861
# [252] *(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:1550
# [253] *(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UnitUpperTriangular) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:1566
# [254] *(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:1643
# [255] *(A::LinearAlgebra.AbstractTriangular, B::AbstractVector{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:1652
# [256] *(A::LinearAlgebra.AbstractTriangular, B::AbstractMatrix{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:1652
# [257] *(A::LinearAlgebra.AbstractQ, b::StridedVector{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/qr.jl:568
# [258] *(A::LinearAlgebra.AbstractQ, B::StridedMatrix{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/qr.jl:580
# [259] *(Q::LinearAlgebra.AbstractQ, adjB::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(StridedVecOrMat{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/qr.jl:635
# [260] *(z::Complex, w::Complex) in Base at complex.jl:277
# [261] *(A::AbstractMatrix{T}, R::LinearAlgebra.AbstractRotation{S}) where {T, S} in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/givens.jl:20
# [262] *(A::AbstractMatrix{T} where T, adjB::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Hermitian{Complex{T}, S}, LinearAlgebra.Symmetric{T, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:607
# [263] *(A::AbstractVector{T} where T, adjR::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractRotation}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/givens.jl:13
# [264] *(A::AbstractMatrix{T} where T, adjR::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:LinearAlgebra.AbstractRotation}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/givens.jl:14
# [265] *(A::AbstractMatrix{T} where T, transB::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}, LinearAlgebra.Symmetric{Complex{T}, S}} where {T<:Real, S})}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/symmetric.jl:603
# [266] *(a::AbstractVector{T} where T, transB::LinearAlgebra.Transpose{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:55
# [267] *(A::AbstractArray, B::Dates.Period) in Dates at /opt/julia-1.6.0/share/julia/stdlib/v1.6/Dates/src/periods.jl:98
# [268] *(A::AbstractArray, B::Number) in Base at arraymath.jl:55
# [269] *(A::AbstractMatrix{T} where T, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/triangular.jl:1694
# [270] *(G1::LinearAlgebra.Givens{T}, G2::LinearAlgebra.Givens{T}) where T in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/givens.jl:396
# [271] *(A::SparseArrays.AbstractSparseMatrixCSC, x::SparseArrays.AbstractSparseVector{Tv, Ti} where {Tv, Ti}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/sparsevector.jl:1761
# [272] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}, LinearAlgebra.LowerTriangular{Tv, var"#s831"} where var"#s831"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}, LinearAlgebra.UpperTriangular{Tv, var"#s832"} where var"#s832"<:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, var"#s832", Tuple{Base.Slice{Base.OneTo{Int64}}, I}, L} where {I<:AbstractUnitRange, var"#s832"<:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, L}}} where {Tv, Ti}, B::SparseArrays.AbstractSparseVector{Tv, Ti} where {Tv, Ti}) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:163
# [273] *(A::Union{DenseMatrix{Ta}, Base.ReinterpretArray{Ta, 2, S, A, IsReshaped} where {A<:Union{SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, IsReshaped, S}, Base.ReshapedArray{Ta, 2, A, MI} where {A<:Union{Base.ReinterpretArray{T, N, S, A, IsReshaped} where {T, N, A<:Union{SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, IsReshaped, S}, SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, N} where N}}, SubArray{Ta, 2, A, I, L} where {A<:Union{Base.ReinterpretArray{T, N, S, A, IsReshaped} where {T, N, A<:Union{SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, IsReshaped, S}, Base.ReshapedArray{T, N, A, MI} where {T, N, A<:Union{Base.ReinterpretArray{T, N, S, A, IsReshaped} where {T, N, A<:Union{SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, IsReshaped, S}, SubArray{T, N, A, I, true} where {T, N, A<:DenseArray, I<:Union{Tuple{Vararg{Real, N} where N}, Tuple{AbstractUnitRange, Vararg{Any, N} where N}}}, DenseArray}, MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, N} where N}}, DenseArray}, I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex, Base.ReshapedArray{T, N, A, Tuple{}} where {T, N, A<:AbstractUnitRange}}, N} where N}, L}, LinearAlgebra.LowerTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UnitLowerTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UnitUpperTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UpperTriangular{Ta, S} where S<:AbstractMatrix{Ta}}, x::SparseArrays.AbstractSparseVector{Tx, Ti} where Ti) where {Ta, Tx} in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/sparsevector.jl:1536
# [274] *(A::SparseArrays.AbstractSparseMatrixCSC, D::LinearAlgebra.Diagonal) in SparseArrays at /opt/julia-1.6.0/share/julia/stdlib/v1.6/SparseArrays/src/linalg.jl:148
# [275] *(A::AbstractMatrix{T} where T, D::LinearAlgebra.Diagonal) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/diagonal.jl:199
# [276] *(A::LinearAlgebra.LQPackedQ, B::StridedVecOrMat{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/lq.jl:191
# [277] *(A::LinearAlgebra.LQPackedQ, adjB::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(StridedVecOrMat{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/lq.jl:215
# [278] *(u::AbstractVector{T} where T, v::Union{LinearAlgebra.Adjoint{T, var"#s832"}, LinearAlgebra.Transpose{T, var"#s832"}} where {T, var"#s832"<:(AbstractVector{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/adjtrans.jl:302
# [279] *(a::AbstractVector{T} where T, adjB::LinearAlgebra.Adjoint{var"#s832", var"#s831"} where {var"#s832", var"#s831"<:(AbstractMatrix{T} where T)}) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:59
# [280] *(A::AbstractMatrix{T} where T, B::AbstractMatrix{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:151
# [281] *(a::AbstractVector{T} where T, B::AbstractMatrix{T} where T) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:63
# [282] *(A::AbstractMatrix{T}, x::AbstractVector{S}) where {T, S} in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/matmul.jl:49
# [283] *(z::Complex{Bool}, x::Bool) in Base at complex.jl:291
# [284] *(z::Complex, x::Bool) in Base at complex.jl:298
# [285] *(z::Complex{Bool}, x::Real) in Base at complex.jl:309
# [286] *(z::Complex, x::Real) in Base at complex.jl:321
# [287] *(x::Rational{BigInt}, y::Rational{BigInt}) in Base.GMP.MPQ at gmp.jl:910
# [288] *(x::Rational, y::Rational) in Base at rational.jl:308
# [289] *(x::BigInt, y::BigInt) in Base.GMP at gmp.jl:479
# [290] *(a::BigInt, b::BigInt, c::BigInt) in Base.GMP at gmp.jl:519
# [291] *(a::BigInt, b::BigInt, c::BigInt, d::BigInt) in Base.GMP at gmp.jl:520
# [292] *(a::BigInt, b::BigInt, c::BigInt, d::BigInt, e::BigInt) in Base.GMP at gmp.jl:521
# [293] *(x::BigInt, c::Union{UInt16, UInt32, UInt64, UInt8}) in Base.GMP at gmp.jl:538
# [294] *(x::BigInt, c::Union{Int16, Int32, Int64, Int8}) in Base.GMP at gmp.jl:540
# [295] *(c::BigInt, x::BigFloat) in Base.MPFR at mpfr.jl:400
# [296] *(::Missing) in Base at missing.jl:101
# [297] *(::Missing, ::Missing) in Base at missing.jl:115
# [298] *(::Missing, ::Number) in Base at missing.jl:116
# [299] *(d::Missing, x::AbstractString) in Base at missing.jl:175
# [300] *(r::Regex) in Base at regex.jl:706
# [301] *(r1::Union{Regex, AbstractChar, AbstractString}, rs::Union{Regex, AbstractChar, AbstractString}...) in Base at regex.jl:685
# [302] *(x::Float32, y::Float32) in Base at float.jl:331
# [303] *(x::Float64, y::Float64) in Base at float.jl:332
# [304] *(x::Bool, y::Bool) in Base at bool.jl:94
# [305] *(a::Integer, b::Integer) in Base at int.jl:919
# [306] *(x::Bool, y::T) where T<:AbstractFloat in Base at bool.jl:105
# [307] *(x::Bool, z::Complex{Bool}) in Base at complex.jl:290
# [308] *(x::Real, z::Complex{Bool}) in Base at complex.jl:308
# [309] *(x::Bool, z::Complex) in Base at complex.jl:297
# [310] *(x::Real, z::Complex) in Base at complex.jl:320
# [311] *(x::Bool, y::AbstractIrrational) in Base at irrationals.jl:158
# [312] *(x::BigFloat, y::BigFloat) in Base.MPFR at mpfr.jl:364
# [313] *(x::BigFloat, c::Union{UInt16, UInt32, UInt64, UInt8}) in Base.MPFR at mpfr.jl:371
# [314] *(x::BigFloat, c::Union{Int16, Int32, Int64, Int8}) in Base.MPFR at mpfr.jl:379
# [315] *(x::BigFloat, c::Union{Float16, Float32, Float64}) in Base.MPFR at mpfr.jl:387
# [316] *(x::BigFloat, c::BigInt) in Base.MPFR at mpfr.jl:395
# [317] *(a::BigFloat, b::BigFloat, c::BigFloat) in Base.MPFR at mpfr.jl:536
# [318] *(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat) in Base.MPFR at mpfr.jl:542
# [319] *(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat, e::BigFloat) in Base.MPFR at mpfr.jl:549
# [320] *(B::BitMatrix, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/uniformscaling.jl:259
# [321] *(x::AbstractMatrix{var"#s79"} where var"#s79"<:Number) in Base at abstractarraymath.jl:98
# [322] *(A::AbstractMatrix{T} where T, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/uniformscaling.jl:261
# [323] *(v::AbstractVector{T} where T, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /opt/julia-1.6.0/share/julia/stdlib/v1.6/LinearAlgebra/src/uniformscaling.jl:262
# [324] *(x::Float16, y::Float16) in Base at float.jl:330
# [325] *(x::Number) in Base at operators.jl:516
# [326] *(x::T, y::T) where T<:Number in Base at promotion.jl:397
# [327] *(x::Number, y::Number) in Base at promotion.jl:322
# [328] *(a, b, c, xs...) in Base at operators.jl:560

# %% [markdown]
# ## Complex Numbers

# %%
(1 + 2im) + (3 + im)
# Out:
# 4 + 3im

# %%
 @which (1 + 2im) + (3 + im)
# Out:
# +(z::Complex, w::Complex) in Base at complex.jl:275

# %% [markdown]
# ## Grab the data

# %%
download(url, "covid_data.csv")
# Out:
# "covid_data.csv"

# %%
readdir()
# Out:
# 5-element Vector{String}:
#  ".git"
#  ".ipynb_checkpoints"
#  "Exploring data on COVID-19.ipynb"
#  "README.md"
#  "covid_data.csv"

# %%
# using Pkg # Julia package manager in Julia
# Pkg.add("CSV")
# Pkg.add("DataFrames")

# %%
using CSV
using DataFrames

# %%
data = CSV.read("covid_data.csv", DataFrame)
# Out:
# 274×437 DataFrame
#  Row │ Province/State                     Country/Region       Lat       Long  ⋯
#      │ String?                            String               Float64?  Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ missing                            Afghanistan           33.9391   67.7 ⋯
#    2 │ missing                            Albania               41.1533   20.1
#    3 │ missing                            Algeria               28.0339    1.6
#    4 │ missing                            Andorra               42.5063    1.5
#    5 │ missing                            Angola               -11.2027   17.8 ⋯
#    6 │ missing                            Antigua and Barbuda   17.0608  -61.7
#    7 │ missing                            Argentina            -38.4161  -63.6
#    8 │ missing                            Armenia               40.0691   45.0
#    9 │ Australian Capital Territory       Australia            -35.4735  149.0 ⋯
#   10 │ New South Wales                    Australia            -33.8688  151.2
#   11 │ Northern Territory                 Australia            -12.4634  130.8
#   ⋮  │                 ⋮                           ⋮              ⋮         ⋮  ⋱
#  265 │ missing                            United Kingdom        55.3781   -3.4
#  266 │ missing                            Uruguay              -32.5228  -55.7 ⋯
#  267 │ missing                            Uzbekistan            41.3775   64.5
#  268 │ missing                            Vanuatu              -15.3767  166.9
#  269 │ missing                            Venezuela              6.4238  -66.5
#  270 │ missing                            Vietnam               14.0583  108.2 ⋯
#  271 │ missing                            West Bank and Gaza    31.9522   35.2
#  272 │ missing                            Yemen                 15.5527   48.5
#  273 │ missing                            Zambia               -13.1339   27.8
#  274 │ missing                            Zimbabwe             -19.0154   29.1 ⋯
#                                                 434 columns and 253 rows omitted

# %%
typeof(data)
# Out:
# DataFrame

# %%
rename!(data, 1 => "province", 2 => "country");

# %%
data
# Out:
# 274×437 DataFrame
#  Row │ province                           country              Lat       Long  ⋯
#      │ String?                            String               Float64?  Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ missing                            Afghanistan           33.9391   67.7 ⋯
#    2 │ missing                            Albania               41.1533   20.1
#    3 │ missing                            Algeria               28.0339    1.6
#    4 │ missing                            Andorra               42.5063    1.5
#    5 │ missing                            Angola               -11.2027   17.8 ⋯
#    6 │ missing                            Antigua and Barbuda   17.0608  -61.7
#    7 │ missing                            Argentina            -38.4161  -63.6
#    8 │ missing                            Armenia               40.0691   45.0
#    9 │ Australian Capital Territory       Australia            -35.4735  149.0 ⋯
#   10 │ New South Wales                    Australia            -33.8688  151.2
#   11 │ Northern Territory                 Australia            -12.4634  130.8
#   ⋮  │                 ⋮                           ⋮              ⋮         ⋮  ⋱
#  265 │ missing                            United Kingdom        55.3781   -3.4
#  266 │ missing                            Uruguay              -32.5228  -55.7 ⋯
#  267 │ missing                            Uzbekistan            41.3775   64.5
#  268 │ missing                            Vanuatu              -15.3767  166.9
#  269 │ missing                            Venezuela              6.4238  -66.5
#  270 │ missing                            Vietnam               14.0583  108.2 ⋯
#  271 │ missing                            West Bank and Gaza    31.9522   35.2
#  272 │ missing                            Yemen                 15.5527   48.5
#  273 │ missing                            Zambia               -13.1339   27.8
#  274 │ missing                            Zimbabwe             -19.0154   29.1 ⋯
#                                                 434 columns and 253 rows omitted

# %%
?rename
# Out:
# search: rename rename! propertynames
#   rename(df::AbstractDataFrame, vals::AbstractVector{Symbol};
#          makeunique::Bool=false)
#   rename(df::AbstractDataFrame, vals::AbstractVector{<:AbstractString};
#          makeunique::Bool=false)
#   rename(df::AbstractDataFrame, (from => to)::Pair...)
#   rename(df::AbstractDataFrame, d::AbstractDict)
#   rename(df::AbstractDataFrame, d::AbstractVector{<:Pair})
#   rename(f::Function, df::AbstractDataFrame)
#
#   Create a new data frame that is a copy of df with changed column names. Each
#   name is changed at most once. Permutation of names is allowed.
#
#   Arguments
#   ≡≡≡≡≡≡≡≡≡≡≡
#
#     •  df : the AbstractDataFrame; if it is a SubDataFrame then renaming is
#        only allowed if it was created using : as a column selector.
#
#     •  d : an AbstractDict or an AbstractVector of Pairs that maps the
#        original names or column numbers to new names
#
#     •  f : a function which for each column takes the old name as a String
#        and returns the new name that gets converted to a Symbol
#
#     •  vals : new column names as a vector of Symbols or AbstractStrings of
#        the same length as the number of columns in df
#
#     •  makeunique : if false (the default), an error will be raised if
#        duplicate names are found; if true, duplicate names will be suffixed
#        with _i (i starting at 1 for the first duplicate).
#
#   If pairs are passed to rename (as positional arguments or in a dictionary or
#   a vector) then:
#
#     •  from value can be a Symbol, an AbstractString or an Integer;
#
#     •  to value can be a Symbol or an AbstractString.
#
#   Mixing symbols and strings in to and from is not allowed.
#
#   See also: rename!
#
#   Examples
#   ≡≡≡≡≡≡≡≡≡≡
#
#   julia> df = DataFrame(i = 1, x = 2, y = 3)
#   1×3 DataFrame
#    Row │ i      x      y
#        │ Int64  Int64  Int64
#   ─────┼─────────────────────
#      1 │     1      2      3
#
#   julia> rename(df, :i => :A, :x => :X)
#   1×3 DataFrame
#    Row │ A      X      y
#        │ Int64  Int64  Int64
#   ─────┼─────────────────────
#      1 │     1      2      3
#
#   julia> rename(df, :x => :y, :y => :x)
#   1×3 DataFrame
#    Row │ i      y      x
#        │ Int64  Int64  Int64
#   ─────┼─────────────────────
#      1 │     1      2      3
#
#   julia> rename(df, [1 => :A, 2 => :X])
#   1×3 DataFrame
#    Row │ A      X      y
#        │ Int64  Int64  Int64
#   ─────┼─────────────────────
#      1 │     1      2      3
#
#   julia> rename(df, Dict("i" => "A", "x" => "X"))
#   1×3 DataFrame
#    Row │ A      X      y
#        │ Int64  Int64  Int64
#   ─────┼─────────────────────
#      1 │     1      2      3
#
#   julia> rename(uppercase, df)
#   1×3 DataFrame
#    Row │ I      X      Y
#        │ Int64  Int64  Int64
#   ─────┼─────────────────────
#      1 │     1      2      3
